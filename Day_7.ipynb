# %% [markdown]
# <a href="https://colab.research.google.com/github/faryal16/Python_Coding_Challenges/blob/main/Day_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 🚀 Mission:
# Create a simple quiz game where the user answers multiple-choice questions.

import random
import time

# Welcome message
print("\t\t🎉 Welcome to the ultimate Quiz Game!🎉\n")
player_name = input("Enter your name: ".strip().title())
print(f"\nHello, {player_name}! Get ready for a fun and challenging quiz. 🧠")

# Countdown Timer for before Quiz begin
print("\nThe quiz will begin in...")
for i in range(3, 0 ,-1):
  print(i)
  time.sleep(1)

print("\n🚀Let's begin\n")

# Instructions
print("📌 Instructions:")
print("🔹 You will be asked 5 multiple-choice questions.")
print("🔹 You have **10 seconds** to answer each question.")
print("🔹 Type **A, B, C, or D** to select your answer.")
print("🔹 Each correct answer gives you **1 point**.")
print("🔹 Let's see how many you can get right! 🎯")
print("\n---------------------------------------------\n")

# Question Bank
questions = [
    {"question": "Which is the largest ocean on Earth?", "options": ["A) Atlantic", "B) Indian", "C) Arctic", "D) Pacific"], "answer": "D"},
    {"question": "How many legs does a spider have?", "options": ["A) 6", "B) 8", "C) 10", "D) 12"], "answer": "B"},
    {"question": "Which gas do plants absorb from the atmosphere?", "options": ["A) Oxygen", "B) Carbon Dioxide", "C) Nitrogen", "D) Hydrogen"], "answer": "B"},
    {"question": "What is the square root of 64?", "options": ["A) 6", "B) 7", "C) 8", "D) 9"], "answer": "C"},
    {"question": "Who painted the Mona Lisa?", "options": ["A) Vincent van Gogh", "B) Pablo Picasso", "C) Leonardo da Vinci", "D) Michelangelo"], "answer": "C"},
    {"question": "Which planet is closest to the Sun?", "options": ["A) Earth", "B) Mars", "C) Mercury", "D) Venus"], "answer": "C"},
    {"question": "What is the currency of Japan?", "options": ["A) Won", "B) Yen", "C) Ringgit", "D) Peso"], "answer": "B"},
    {"question": "Who wrote 'Hamlet'?", "options": ["A) Charles Dickens", "B) William Shakespeare", "C) Mark Twain", "D) Jane Austen"], "answer": "B"},
    {"question": "How many continents are there on Earth?", "options": ["A) 5", "B) 6", "C) 7", "D) 8"], "answer": "C"},
    {"question": "What is the boiling point of water in Celsius?", "options": ["A) 90°C", "B) 95°C", "C) 100°C", "D) 110°C"], "answer": "C"},
]

# Select 5 random question
quiz_questions = random.sample(questions, 5)

score= 0

for i, q in enumerate(quiz_questions, start=1):
    print(f"\nQuestion {i}: {q['question']}")
    for option in q['options']:
        print(option)

    start_time = time.time()
    user_answer = input("\nYour answer (A, B, C, D): ").strip().upper()

    # Check time limit
    if time.time() - start_time > 10:
      print("⏳ Time's up! ❌ No points for this question.")
      continue

    if user_answer == q['answer']:
        print("✅ Correct! 🎉")
        score += 1
    else:
        print(f"❌ Incorrect! The correct answer is {q['answer']}.")

# Final Score & Performance Review
print("\n---------------------------------------------")
print(f"🎯 Final Score for {player_name}: {score}/5\n")

if score == 5:
    print("🏆 Perfect Score! You're a genius! 🎉")
elif score >= 3:
    print("🔥 Great job! You did really well! 💪")
elif score >= 1:
    print("😊 Good effort! Keep practicing! 📚")
else:
    print("😢 Better luck next time! Keep learning! 💡")

print("\nThanks for playing! See you next time! 👋")
# Out:
# 		🎉 Welcome to the ultimate Quiz Game!🎉
#
# Enter Your Name:Faryal junaid
#
# Hello, Faryal junaid! Get ready for a fun and challenging quiz. 🧠
#
# The quiz will begin in...
# 3
# 2
# 1
#
# 🚀Let's begin
#
# 📌 Instructions:
# 🔹 You will be asked 5 multiple-choice questions.
# 🔹 You have **10 seconds** to answer each question.
# 🔹 Type **A, B, C, or D** to select your answer.
# 🔹 Each correct answer gives you **1 point**.
# 🔹 Let's see how many you can get right! 🎯
#
# ---------------------------------------------
#
#
# Question 1: How many legs does a spider have?
# A) 6
# B) 8
# C) 10
# D) 12
#
# Your answer (A, B, C, D): b
# ✅ Correct! 🎉
#
# Question 2: What is the boiling point of water in Celsius?
# A) 90°C
# B) 95°C
# C) 100°C
# D) 110°C
#
# Your answer (A, B, C, D): c
# ✅ Correct! 🎉
#
# Question 3: Who painted the Mona Lisa?
# A) Vincent van Gogh
# B) Pablo Picasso
# C) Leonardo da Vinci
# D) Michelangelo
#
# Your answer (A, B, C, D): b
# ❌ Incorrect! The correct answer is C.
#
# ...
